# %%
import pandas as pd
data=pd.read_csv('Reviews.csv')
print(data)
# Out:
#                                                 Review  Liked
# 0                             Wow... Loved this place.      1
# 1                                   Crust is not good.      0
# 2            Not tasty and the texture was just nasty.      0
# 3    Stopped by during the late May bank holiday of...      1
# 4    The selection on the menu was great and so wer...      1
# ..                                                 ...    ...
# 995  I think food should have flavor and texture an...      0
# 996                           Appetite instantly gone.      0
# 997  Overall I was not impressed and would not go b...      0
# 998  The whole experience was underwhelming, and I ...      0
# 999  Then, as if I hadn't wasted enough of my life ...      0
#
# [1000 rows x 2 columns]

# %%
k.head()
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
k.head(10)
# Out:
#                                               Review  Liked
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1
# 5     Now I am getting angry and I want my damn pho.      0
# 6              Honeslty it didn't taste THAT fresh.)      0
# 7  The potatoes were like rubber and you could te...      0
# 8                          The fries were great too.      1
# 9                                     A great touch.      1

# %%
k.tail(50)
# Out:
#                                                 Review  Liked
# 950         It wasn't busy at all and now we know why.      0
# 951  The tables outside are also dirty a lot of the...      0
# 952  The ambiance here did not feel like a buffet s...      0
# 953                               Con: spotty service.      0
# 954  The fries were not hot, and neither was my bur...      0
# 955                      But then they came back cold.      0
# 956     Then our food came out, disappointment ensued.      0
# 957            The real disappointment was our waiter.      0
# 958  My husband said she was very rude... did not e...      0
# 959  The only reason to eat here would be to fill u...      0
# 960  Insults, profound deuchebaggery, and had to go...      0
# 961  If someone orders two tacos don't' you think i...      0
# 962  She was quite disappointed although some blame...      0
# 963  After all the rave reviews I couldn't wait to ...      0
# ...

# %%
k.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  1000 non-null   object
#  1   Liked   1000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 15.8+ KB

# %%
k.isnull().sum()
# Out:
# Review    0
# Liked     0
# dtype: int64

# %%
k.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
# sea born creates 3D plots
import seaborn as sb
import matplotlib.pyplot as pt

# %%
from wordcloud import WordCloud

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Windows\anaconda3\python.exe

# %%
pip install some_package
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for some_package: filename=some_package-0.1-py3-none-any.whl size=1434 sha256=83a61a18a4cf8110522dc85fea628c7a38e08866334d47d8c87eaaaa71c81f3b
#   Stored in directory: c:\users\windows\appdata\local\pip\cache\wheels\79\65\17\0555c887f2a873f0170c91acb34c531cdc4e15546962aab916
# Successfully built some_package
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wordcloud
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/300.2 kB 279.3 kB/s eta 0:00:01
#    ----------- --------------------------- 92.2/300.2 kB 401.6 kB/s eta 0:00:01
#    ----------- --------------------------- 92.2/300.2 kB 401.6 kB/s eta 0:00:01
#    ---------------------- --------------- 174.1/300.2 kB 581.0 kB/s eta 0:00:01
#    ---------------------- --------------- 174.1/300.2 kB 581.0 kB/s eta 0:00:01
#    -------------------------------- ----- 256.0/300.2 kB 628.5 kB/s eta 0:00:01
#    -------------------------------------- 300.2/300.2 kB 687.0 kB/s eta 0:00:00
# ...

# %%
ct=" ".join(k['Review']) # combine alll reviews texts into  one line
print(ct)
# Out:
# Wow... Loved this place. Crust is not good. Not tasty and the texture was just nasty. Stopped by during the late May bank holiday off Rick Steve recommendation and loved it. The selection on the menu was great and so were the prices. Now I am getting angry and I want my damn pho. Honeslty it didn't taste THAT fresh.) The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer. The fries were great too. A great touch. Service was very prompt. Would not go back. The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced. I tried the Cape Cod ravoli, chicken, with cranberry...mmmm! I was disgusted because I was pretty sure that was human hair. I was shocked because no signs indicate cash only. Highly recommended. Waitress was a little slow in service. This place is not worth your time, let alone Vegas. did not like at all. The Burrittos Blah! The food, amazing. Service is also cute. I could care l
# ...

# %%
wordcloud=WordCloud(width=1000,height=500,background_color='white').generate(ct)
# print(wordcloud)
pt.figure(figsize=(10, 5))
pt.imshow(wordcloud, interpolation='bilinear')
pt.title('Resturent Reviews')
pt.axis('off')
pt.show()

# %%
from collections import Counter
tw=['good','greate','food','preety']
a_w="".join(k['Review']).lower().split()
# print(a_w)

# %%
# counting target words
wc=Counter(a_w)
# print(w_c)
# Out:
# Counter({'the': 402, 'and': 380, 'was': 291, 'a': 227, 'to': 214, 'is': 170, 'i': 165, 'of': 124, 'not': 104, 'for': 101, 'in': 100, 'this': 94, 'it': 82, 'food': 80, 'place': 77, 'with': 72, 'had': 66, 'be': 65, 'very': 62, 'are': 62, 'were': 61, 'that': 60, 'have': 60, 'so': 58, 'but': 56, 'good': 55, 'my': 52, 'at': 52, 'you': 51, 'on': 49, 'like': 44, 'we': 44, 'service': 42, 'great': 40, 'they': 39, 'go': 39, 'our': 36, 'here': 36, 'time': 34, 'back': 34, 'really': 32, 'just': 30, 'as': 30, 'will': 30, 'an': 28, 'all': 28, 'would': 25, 'been': 23, 'ever': 23, 'your': 23, 'only': 23, 'their': 23, "don't": 22, 'also': 21, 'there': 21, 'from': 21, 'no': 20, 'came': 20, 'out': 20, 'never': 20, 'up': 19, 'get': 19, 'which': 19, 'one': 19, 'or': 19, 'by': 18, 'friendly': 18, 'some': 18, 'did': 18, 'got': 18, '-': 18, 'going': 18, 'eat': 17, 'nice': 17, 'much': 17, 'about': 17, "won't": 17, 'even': 17, 'could': 16, 'what': 16, 'pretty': 16, 'restaurant': 16, 'think': 16, 'more': 16, 'l
# ...

# %%
# for i in tw:
#     if i in w_c:
#         print(w_c(i))
twc={x: wc[x] for x in tw}
print(twc)
# Out:
# {'good': 55, 'greate': 0, 'food': 80, 'preety': 0}

# %%
pt.figure(figsize=(8,6))
pt.bar(twc.keys(),twc.values())
pt.xlabel('REVIEWS')
pt.ylabel('CHART')
# Out:
# Text(0, 0.5, 'CHART')

# %%
#lowering text
loweredtext=data['Review'].str.lower()
print(loweredtext)
# Out:
# 0                               wow... loved this place.
# 1                                     crust is not good.
# 2              not tasty and the texture was just nasty.
# 3      stopped by during the late may bank holiday of...
# 4      the selection on the menu was great and so wer...
#                              ...
# 995    i think food should have flavor and texture an...
# 996                             appetite instantly gone.
# 997    overall i was not impressed and would not go b...
# 998    the whole experience was underwhelming, and i ...
# 999    then, as if i hadn't wasted enough of my life ...
# Name: Review, Length: 1000, dtype: object

# %%
import nltk
nltk.download('punkt')
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Windows\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Windows\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
#tokenization
from nltk.tokenize import word_tokenize
data['Tokens']=data['Review'].apply(word_tokenize)
print(data['Tokens'])
# Out:
# 0                      [Wow, ..., Loved, this, place, .]
# 1                              [Crust, is, not, good, .]
# 2      [Not, tasty, and, the, texture, was, just, nas...
# 3      [Stopped, by, during, the, late, May, bank, ho...
# 4      [The, selection, on, the, menu, was, great, an...
#                              ...
# 995    [I, think, food, should, have, flavor, and, te...
# 996                       [Appetite, instantly, gone, .]
# 997    [Overall, I, was, not, impressed, and, would, ...
# 998    [The, whole, experience, was, underwhelming, ,...
# 999    [Then, ,, as, if, I, had, n't, wasted, enough,...
# Name: Tokens, Length: 1000, dtype: object

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stop_words=set(stopwords.words['english'])
data['Token']=data['Review'].apply(lambda x : [ word for word in word_tokenize(x) if word not in stop_words])
print(data['Token'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 stop_words=set(stopwords.words['english'])
#       2 data['Token']=data['Review'].apply(lambda x : [ word for word in word_tokenize(x) if word not in stop_words])
#       3 print(data['Token'])
#
# TypeError: 'method' object is not subscriptable

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
data['stemmed'] = data['Review'].apply(lambda x : " ".join(stemmer.stem(word) for word in word_tokenize(x)))

# %%
print(data['stemmed'])
# Out:
# 0                               wow ... love thi place .
# 1                                    crust is not good .
# 2               not tasti and the textur wa just nasti .
# 3      stop by dure the late may bank holiday off ric...
# 4      the select on the menu wa great and so were th...
#                              ...
# 995    i think food should have flavor and textur and...
# 996                             appetit instantli gone .
# 997      overal i wa not impress and would not go back .
# 998    the whole experi wa underwhelm , and i think w...
# 999    then , as if i had n't wast enough of my life ...
# Name: stemmed, Length: 1000, dtype: object

# %%
data['stemmed'].value_counts()
# Out:
# stemmed
# # name ?                                                                                                                               4
# the food wa terribl .                                                                                                                  2
# i would not recommend thi place .                                                                                                      2
# i love thi place .                                                                                                                     2
# i wo n't be back .                                                                                                                     2
#                                                                                                                                       ..
# omg , the food wa delicioso !                                                                                                          1
# ...

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Windows\AppData\Roaming\nltk_data...

# %%
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
data['lemmatized']=data['Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word,pos=wordnet.VERB) for word in word_tokenize(x)]))
print(data['lemmatized'])
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Windows\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 nltk.download('wordnet')
#       2 lemmatizer = WordNetLemmatizer()
# ----> 3 data['lemmatized']=data['Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word,pos=wordnet.VERB) for word in word_tokenize(x)]))
#       4 print(data['lemmatized'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
# ...

# %%
#remove the numbers
import re
data['No_Numbers']=data['Review'].apply(lambda x:re.sub(r'\d+',' ',x))
print(data['No_Numbers'])
# Out:
# 0                               Wow... Loved this place.
# 1                                     Crust is not good.
# 2              Not tasty and the texture was just nasty.
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone.
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming, and I ...
# 999    Then, as if I hadn't wasted enough of my life ...
# Name: No_Numbers, Length: 1000, dtype: object

# %%
data['cleaned_text'] = data['Review'].apply(lambda x: re.sub(r'[^A-Za-z0-9\s]',x))
print(data['cleaned_text'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 data['cleaned_text'] = data['Review'].apply(lambda x: re.sub(r'[^A-Za-z0-9\s]',x))
#       2 print(data['cleaned_text'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# ...

# %%
pip install emoji
# Out:
# ...
#    ---------------------------------------- 0.0/431.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/431.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/431.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/431.4 kB ? eta -:--:--
#    ---------------------------------------- 0.0/431.4 kB ? eta -:--:--
#     --------------------------------------- 10.2/431.4 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/431.4 kB 660.6 kB/s eta 0:00:01
#    --- ----------------------------------- 41.0/431.4 kB 393.8 kB/s eta 0:00:01
#    -------- ------------------------------ 92.2/431.4 kB 525.1 kB/s eta 0:00:01
#    ----------------- -------------------- 194.6/431.4 kB 908.0 kB/s eta 0:00:01
#    -------------------------- ------------- 286.7/431.4 kB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 389.1/431.4 kB 1.3 MB/s eta 0:00:01
# ...

# %%
import emoji
data['Emoji'] = data['Review'].apply(emoji.demojize)

# %%
print(data['Emoji'])
# Out:
# 0                               Wow... Loved this place.
# 1                                     Crust is not good.
# 2              Not tasty and the texture was just nasty.
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone.
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming, and I ...
# 999    Then, as if I hadn't wasted enough of my life ...
# Name: Emoji, Length: 1000, dtype: object

# %%
#remove html tags
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

# %%
data['cleaned']=data['Review'].apply(lambda x: BeautifulSoup(x,"html.parser").get_text())
# Out:
# C:\Users\Windows\AppData\Local\Temp\ipykernel_1152\3259983302.py:1: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   data['cleaned']=data['Review'].apply(lambda x: BeautifulSoup(x,"html.parser").get_text())

# %%
print(data['cleaned'])
# Out:
# 0                               Wow... Loved this place.
# 1                                     Crust is not good.
# 2              Not tasty and the texture was just nasty.
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone.
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming, and I ...
# 999    Then, as if I hadn't wasted enough of my life ...
# Name: cleaned, Length: 1000, dtype: object
